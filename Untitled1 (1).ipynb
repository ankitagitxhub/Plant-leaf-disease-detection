# %%
# Plant Disease Detection using CNN (Minimal Demo)
# Author: Ankita Sahoo

# -------------------------------
# 1. Import Libraries
# -------------------------------
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

print("✅ Libraries Imported Successfully")

# -------------------------------
# 2. Data Preparation (Dummy / Replace with Kaggle Dataset)
# -------------------------------
# For demo, using CIFAR-10 dataset (you can replace with plant dataset later)
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

print("✅ Data Loaded:", x_train.shape, y_train.shape)

# -------------------------------
# 3. Build CNN Model
# -------------------------------
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(10, activation='softmax')  # 10 classes (replace with disease classes)
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

print("✅ CNN Model Built")

# -------------------------------
# 4. Train Model
# -------------------------------
history = model.fit(x_train, y_train, epochs=5,
                    validation_data=(x_test, y_test))

# -------------------------------
# 5. Evaluate Model
# -------------------------------
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print("\n🎯 Test Accuracy:", test_acc)

# -------------------------------
# 6. Visualize Training
# -------------------------------
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# -------------------------------
# 7. Prediction (Demo)
# -------------------------------
import numpy as np
sample_img = x_test[0].reshape(1,32,32,3)
prediction = model.predict(sample_img)
print("Predicted Class:", prediction.argmax())
# Out:
# ✅ Libraries Imported Successfully
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ✅ Data Loaded: (50000, 32, 32, 3) (50000, 1)
# ✅ CNN Model Built
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 51ms/step - accuracy: 0.3577 - loss: 1.7400 - val_accuracy: 0.5732 - val_loss: 1.2090
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 49ms/step - accuracy: 0.5647 - loss: 1.2294 - val_accuracy: 0.6276 - val_loss: 1.0756
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 46ms/step - accuracy: 0.6263 - loss: 1.0618 - val_accuracy: 0.6675 - val_loss: 0.9652
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 46ms/step - accuracy: 0.6635 - loss: 0.9619 - val_accuracy: 0.6748 - val_loss: 0.9369
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 74s 47ms/step - accuracy: 0.6882 - loss: 0.8840 - val_accuracy: 0.6764 - val_loss: 0.9376
# 313/313 - 5s - 16ms/step - accuracy: 0.6764 - loss: 0.9376
#
# 🎯 Test Accuracy: 0.6764000058174133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Predicted Class: 3
